# %% [markdown]
# # DAV 5400  HIV-AIDS-Diagnoses-Analysis
#
# #### Author: Lokesh Dondapati
# My Github repository link https://github.com/LokeshDondapati/HIV-AIDS-Diagnoses-Analysis

# %% [markdown]
# # Part 1: Introduction
#
# In this project, the datasets focuses on 'HIV/AIDS Diagnoses by Neighborhood, SEX, Age Group, and Race/Ethnicity' in New York. The dataset comprises data related to HIV/AIDS diagnoses per population, age, and neighborhood. Race/ethnicity attributes include Black, Asian/Pacific Islander, White, etc. The dataset provides information on demographics, such as age and location, as well as variables indicating diagnoses per population. The dataset's temporal aspect allows tracking engagement trends over time, making it an ideal subject for analysis. This dataset contains all diagnoses information for different age groups and tends to provide accurate information about cities.
#
# The main purpose of this analysis is to gain a good understanding of data within various categories and to explore their relationships across other variables. By examining the data, we aim to draw meaningful insights.
#
# To achieve this, I am going to follow the below steps:
#
# Data Exploration
# Exploratory Data Analysis (EDA)
# Inference
# Conclusion
#
#
#
# ## Research Question:
# 1.How does the distribution of concurrent HIV/AIDS diagnoses vary across different age groups, race/ethnicity groups, neighbhorhood and gender, and what are the gender-specific patterns within race/ethnicity group?
#
#
# 2.Are there specific age groups with higher or lower diagnosis rates?
#
# 3.What is the comparative analysis of the mean rates of HIV/AIDS diagnoses between different boroughs?

# %% [markdown]
# # Part 2: Data Summary
#
# Data Source:
#
# The data for this analysis was acquired from the New York City Open Data website and it was publicly available. The dataset is titled 'HIV/AIDS Diagnoses by Neighborhood, Age Group, and Race/Ethnicity' and is publicly available at the following link https://data.cityofnewyork.us/Health/HIV-AIDS-Diagnoses-by-Neighborhood-Age-Group-and-R/dxnu-p2qd. This dataset provides information about HIV/AIDS daignoses in different borough, for different race/ethnicity and provides information for different age groups in NEWYORK state.
#
# Number of Use Cases: There are 21036 usecases(rows).
#
# Number of Attributes: Calculated the number of attributes (columns) in  dataset using the shape attribute of a Pandas DataFrame and there are 11 attributes .
#
# Data Types of Attributes: To display the data types of each attribute in dataset, below is the code.
#
# Additional Data Source:
#
# This dataset will give additional information of gender wise those are doing daignosis of HIV/AIDS which first dataset doesn't contain.
#
# Same like above, data for this analysis was acquired from the New York City Open Data website and it was publicly available. The dataset is titled 'HIV/AIDS Diagnoses by Neighborhood, SEX, and Race/Ethnicity' and is publicly available at the following link https://data.cityofnewyork.us/Health/HIV-AIDS-Diagnoses-by-Neighborhood-Sex-and-Race-Et/ykvb-493p. This dataset provides information about HIV/AIDS daignoses in different borough, for different race/ethnicity and provides information for different genders in NEWYORK state.
#
# Number of Use Cases: There are 8976 usecases(rows).
#
# Number of Attributes: There are 11 attributes .

# %% [markdown]
# ### Code explanation:
#
# This Python code utilizes the pandas library to perform a series of operations on a dataset stored in a CSV file. First, it loads the dataset from a specific URL and stores it as a pandas DataFrame named "data." It then calculates and displays two key statistics: the number of use cases, which corresponds to the rows in the dataset, and the number of attributes, equivalent to the dataset's columns. Furthermore, it extracts and lists the data types for each attribute (column) in the dataset. This code is a helpful starting point for understanding the dataset's size, structure, and the data types used in each column, all of which are fundamental aspects when working with data analysis and manipulation in Python.

# %%
# from package importing module
from diagnoses_analysis import data_summary

# url of dataset
url = "https://raw.githubusercontent.com/LokeshDondapati/project1/main/HIV_AIDS_Diagnoses_by_Neighborhood__Age_Group__and_Race_Ethnicity.csv"

df = data_summary.DataSummary(url).data_summary()
# Out:
# Use Cases: 21036
# Attributes: 11
# Data Types for Attribute: YEAR                                                                    int64
# NEIGHBORHOOD                                                           object
# RACE/ETHNICITY                                                         object
# AGE                                                                    object
# TOTAL NUMBER OF HIV DIAGNOSES                                          object
# HIV DIAGNOSES PER 100,000 POPULATION                                   object
# TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAGNOSES                          object
# PROPORTION OF CONCURRENT HIV/AIDS DIAGNOSES AMONG ALL HIV DIAGNOSES    object
# TOTAL NUMBER OF AIDS DIAGNOSES                                         object
# AIDS DIAGNOSES PER 100,000 POPULATION                                  object
# Borough                                                                object
# dtype: object

# %% [markdown]
# # Part 3  Exploratory Data Analysis (EDA)
# we first Import the Matplotlib library, which is specifically the pyplot module, which is commonly used for creating various types of plots and charts. Then we add its size and, the bars' color and also  Adds a label to the x-axis & the y-axis. The same applies to Seaborn, It specifies the 'AGE' column from the dataset as the data source for the histogram. we specify that there should be 20 bins (bars) in the histogram, set the bars' color to blue, and add a KDE (Kernel Density Estimation) curve to the plot. The KDE curve is an estimation of the underlying probability density function of the data.
#
# Seaborn provides a higher-level interface for creating aesthetically pleasing and informative statistical visualizations. In this code, it combines a histogram with a KDE curve to provide a more comprehensive view of the data's distribution.

# %% [markdown]
# # Code explanation:
#
# The provided Python code snippet leverages the pandas, matplotlib, and seaborn libraries to carry out a series of tasks on a dataset. It starts by importing these libraries, setting the stage for data manipulation and visualization. The dataset, sourced from a specific URL, is loaded into a pandas DataFrame named "data." Subsequently, summary statistics for the dataset's numerical columns are calculated using the describe() function, which includes metrics such as count, mean, standard deviation, and more. These statistics are stored in a DataFrame called "summary_stats." Lastly, the code prints the summary statistics, offering a preliminary insight into the dataset's central tendencies and variability. This code is a foundational step in data analysis, providing an initial understanding of the dataset's characteristics, and it serves as a launchpad for further exploration and visualization of the data.

# %%
from diagnoses_analysis import eda

# First dataset statistics
# Call the statistics method on the EDA instance.

stat = eda.EdaAnalysis().statistics()
stat.head()
# Out:
#                 YEAR NEIGHBORHOOD RACE/ETHNICITY    AGE  \
# count   21036.000000        21036          21036  21036
# unique           NaN           54             11     12
# top              NaN          All          Black    60+
# freq             NaN         1558           3220   3220
# mean     2015.763548          NaN            NaN    NaN
#
#        TOTAL NUMBER OF HIV DIAGNOSES HIV DIAGNOSES PER 100,000 POPULATION  \
# count                          20935                                19559
# unique                           255                                 1738
# top                                0                                    0
# freq                           11409                                10154
# mean                             NaN                                  NaN
#
#        TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAGNOSES  \
# count                                          21011
# unique                                            94
# ...

# %%
#Second dataset statistics
from diagnoses_analysis import eda

stat=eda.EdaAnalysis().gender_dataset_statistics()
stat.head()
# Out:
#                YEAR   Borough Neighborhood (U.H.F)   SEX RACE/ETHNICITY  \
# count   8976.000000      6048                 8976  8976           8976
# unique          NaN         6                   66     3             11
# top             NaN  Brooklyn                  All  Male            All
# freq            NaN      1512                  760  3392           1528
# mean    2016.360963       NaN                  NaN   NaN            NaN
#
#        TOTAL NUMBER OF HIV DIAGNOSES HIV DIAGNOSES PER 100,000 POPULATION  \
# count                           8970                                 8902
# unique                           306                                 1260
# top                                0                                    0
# freq                            3160                                 3142
# mean                             NaN                                  NaN
#
#        TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAGNOSES  \
# ...

# %% [markdown]
# # Code Explanation
# I created a package "project1" and added all my python files in project1 package. And below iam calling class, functions and methods from py files to do Exploratory data analysis. Detailed code explanation are commented on scripts

# %%
# from package Diagnoses_Analysis importing EDA file
from diagnoses_analysis import eda

# Accessing class from file and accessing function through class
year_attribute = eda.EdaAnalysis().graphical_analysis_matplotlib_year()

# %% [markdown]
# ##### Observation
# During years 2010 to 2013 the HIV/AIDS diagnoses remains in same frequency and in 2020 it peaked

# %%
#from package Diagnoses_Analysis importing EDA file
from diagnoses_analysis import eda

#Accessing class from file and accessing function through class
method=eda.EdaAnalysis().graphical_analysis_seaborn_year()

# %% [markdown]
# #### Observation
# During 40-49 age group HIV/AIDS daignoses are having more daignoses whereas 60+ are also having daignoses rate high

# %%
#from package Diagnoses_Analysis importing EDA file
from diagnoses_analysis import eda

#Accessing class EDA from file and accessing function through class
age_attribute=eda.EdaAnalysis().graphical_analysis_matplotlib_age()

# %% [markdown]
# #### Observation
# This line shows the same thing that from 2010-2013 year daignoses frequency is same and it is at higher level during 2020

# %%
# from package Diagnoses_Analysis importing EDA file
from diagnoses_analysis import eda

# Accessing class EDA from file and accessing function through class
method = eda.EdaAnalysis().graphical_analysis_seaborn_age()

# %% [markdown]
# ##### Observation
#
# During 13-59 age group HIV/AIDS daignoses are at same level whereas people above 60 age group have more daignoses

# %% [markdown]
# # Part4 Inference
# ## Research Question:
# 1.How do age, neighborhood, and race/ethnicity interact in influencing HIV/AIDS diagnoses?
#
# 2.Are there specific age groups with higher or lower diagnosis rates?
#
# 3.What is the comparative analysis of the mean rates of HIV/AIDS diagnoses between different boroughs?
#
#
# The main reason i chose this dataset is to know the HIV/AIDS daignoses that was done in previous years and do analysis on data and also i want to know and analyze in current years how much rate that was increased and how higher rates will this disease go and effect people. Based on my intrest i have two research questions to analyze and get to know about age, neighborhood, and race/ethnicity interact in influencing HIV/AIDS diagnoses?
# Are there specific age groups with higher or lower diagnosis rates?

# %% [markdown]
# ### Code Explanation
# #### Analysis1 module explanation:
# Python code showcases a comprehensive approach to data analysis and visualization using Pandas, Seaborn, and Matplotlib libraries. The primary focus lies in reshaping, grouping, and aggregating data for meaningful insights.
#
# In the initial steps, the dataset undergoes reshaping through the readdata method. The 'AGE' column is split into start and end ages, facilitating numeric conversion and the creation of a 'combined_age' column, streamlining subsequent analyses based on age groups.
#
# The Seaborn analysis section demonstrates the grouping and aggregation process. Data is grouped by combined age and race/ethnicity, with the total number of concurrent HIV/AIDS diagnoses aggregated for each group. A custom color palette is intelligently employed to enhance the visual representation, assigning distinct colors to different race/ethnicity categories. The Seaborn bar plot vividly illustrates the relationships between age, race/ethnicity, and diagnosis counts.
#
# Moving on to the Matplotlib analysis, a similar approach is taken with additional considerations. The dataset is grouped by combined age, neighborhood, and race/ethnicity, and the total number of concurrent HIV/AIDS diagnoses is aggregated. A customized color palette is again employed for visual clarity. The resulting Matplotlib bar plot provides insights into the distribution of diagnoses across different race/ethnicity groups within neighborhoods.
#
# The subsequent Matplotlib analysis shifts focus to ethnicity and sex. The dataset is filtered to exclude rows with 'All' in 'RACE/ETHNICITY' or 'SEX', and the total number of diagnoses is aggregated based on both 'RACE/ETHNICITY' and 'SEX'. The resulting bar plot uses reversed hues, offering a different perspective on the distribution of HIV diagnoses among different ethnicities and sexes.

# %%
# from package Diagnoses_Analysis importing analysis file
from diagnoses_analysis import analysis1

# Accessing class Inference from file and accessing function through class

method = analysis1.Inference()
Seaborn_graphicalanalysis = method.analysis_seaborn()
# Out:
# C:\Users\ldond\Downloads\diagnoses_analysis\analysis1.py:120: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(
# C:\Users\ldond\Downloads\diagnoses_analysis\analysis1.py:185: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(

# %%
#graphical analysis using matplotlib

matplotlib_graphicalanalysis=method.analysis_matplotlib()

# %% [markdown]
# ### Observation
# The analysis of HIV/AIDS data paints a picture of how different factors contribute to the number of diagnoses. When we look at different age groups, it's clear that more people between the ages of 30 and 39 are diagnosed with HIV/AIDS.
#
# Digging deeper into the data, we see that among various racial and ethnic groups, black individuals consistently have the highest number of diagnoses, especially in the 30-39 age range.
#
# Adding gender into the mix, we find that, overall, more males are diagnosed than females. This holds true across different ages and races. Specifically, in the 30-39 age group for black individuals, there are more than 2500 diagnoses for males compared to around 1200 for females.

# %% [markdown]
# ### Code Explanation
# #### Analysis2 module explanation:
# The Python code showcases on analyzing and visualizing the mean of HIV/AIDS diagnoses by age, utilizing Seaborn and Matplotlib libraries. The process begins with reshaping the data through the 'readdata' method, where the 'AGE' column is processed to extract start and end ages, and a new 'combined_age' column is created to represent age ranges. This reshaping enables a more detailed analysis based on age groups.
#
# The subsequent steps, common to both Seaborn and Matplotlib analyses, involve cleaning the 'TOTAL NUMBER OF CONCURRENT HIV/AIDS DIAGNOSES' column by replacing '000*' with NaN, filtering rows based on age conditions, grouping the data by 'combined_age,' and calculating the mean diagnosis rate for each age group.
#
# In the Seaborn analysis, the 'barplot' function is employed to create a visually informative bar plot. The x-axis displays age groups, the y-axis represents the mean of total HIV/AIDS diagnoses, and the 'viridis' color palette enhances visual distinction.
#
# For the Matplotlib analysis, the 'bar' function is used to generate a bar plot. Similar to Seaborn, the x-axis shows age groups, and the y-axis depicts the mean of total HIV/AIDS diagnoses. A green color is chosen for clarity in the visualization.

# %%
# from package Diagnoses_Analysis importing analysis2 file

from diagnoses_analysis import analysis2

# Accessing class Inference from file and accessing function through class

mean = analysis2.Inference()
seaborn_graphicalanalysis = mean.analysis_seaborn()

# %%
#Using matplotlib graphical anlysis

matplotlib_graphicalanalysis=mean.analysis_matplotlib()

# %% [markdown]
# ### Observation
# The analysis reveals that the middle-aged group, specifically individuals aged 30-39, has the highest average number of HIV/AIDS diagnoses. Following closely, the age group of 40-49 also shows a significant number of diagnoses.
#
# On the other hand, the younger age group has the lowest rate of diagnoses. This suggests that individuals in their 30s and 40s tend to have a higher prevalence of HIV/AIDS diagnoses compared to both younger and older age groups. The middle-aged population, therefore, appears to be more affected by these health conditions based on the calculated mean values.

# %% [markdown]
# ### Code Explanation
# #### Analysis2 module explanation:
#  The initial step involves reshaping the data to enhance its analytical capabilities. The 'AGE' column undergoes processing to extract start and end ages, ultimately resulting in the creation of a new 'combined_age' column that signifies age ranges. This reshaping lays the foundation for a more nuanced exploration of the dataset. Simultaneously, the dataset is read and preprocessed to ensure uniformity for subsequent analyses.
#
# Both Seaborn and Matplotlib analyses follow a unified approach. The code systematically cleans the 'TOTAL NUMBER OF HIV/AIDS DIAGNOSES' columns by replacing '000*' with NaN. This meticulous cleaning ensures a consistent representation of numeric values throughout the dataset. Strategic grouping is employed to organize the data. In the Seaborn analysis, grouping is by boroughs, while the Matplotlib analysis extends the scope to include boroughs and sex categories. This deliberate grouping sets the stage for a targeted exploration of HIV/AIDS diagnoses within specific contextual categories.
#
# The heart of the analysis lies in the aggregation phase. Mean diagnosis rates are meticulously computed for each borough in the Seaborn analysis and for each borough/sex combination in the Matplotlib analysis. This aggregation distills the dataset into a succinct summary statistic, enabling a comprehensive understanding of the prevailing trends.
#
# Seaborn's versatile barplot function is harnessed to craft an illustrative bar plot. Boroughs adorn the x-axis, the y-axis quantifies the mean of total HIV/AIDS diagnoses, and distinctive colors distinguish between HIV and AIDS diagnoses. This visual representation facilitates a swift comparison of diagnosis rates across diverse boroughs.
#
# Matplotlib's robust bar function takes center stage, fashioning a bar plot characterized by grouped bars for HIV and AIDS diagnoses. The x-axis accentuates boroughs, the y-axis captures the mean total number of diagnoses, and nuanced colors draw a clear distinction between HIV and AIDS. This visualization complements the Seaborn analysis, offering an additional perspective.

# %%
from diagnoses_analysis import analysis3

# Accessing class Inference from file and accessing function through class

insight = analysis3.Inference()
# Using seaborn graphical anlysis
Seaborn_graphicalanalysis = insight.analysis_seaborn()

# %%
#Using matplotlib graphical anlysis

matplotlib_graphicalanalysis=insight.analysis_matplotlib()

# %% [markdown]
# ### Observation
# In the analysis of HIV and AIDS diagnoses in New York State, we found that, on average, there were 140 diagnoses for HIV and 90 diagnoses for AIDS across all boroughs. Notably, AIDS diagnoses were consistently lower than HIV diagnoses in every borough.
#
# Among the boroughs, the Bronx had the highest rate of both HIV and AIDS individual diagnoses. On the other hand, Staten Island had the lowest rates for both HIV and AIDS diagnoses, which could be attributed to its comparatively lower population. This highlights variations in the prevalence of HIV and AIDS across different boroughs, with the Bronx showing the highest health challenges in this context.

# %% [markdown]
# # Conclusion:
#  The analysis provides a comprehensive understanding of HIV/AIDS diagnoses in New York, considering various factors such as borough, age, ethnicity, and sex.Bronx consistently exhibits the highest rates of both HIV and AIDS diagnoses among the boroughs, while Staten Island generally has the lowest rates.The age group analysis indicates that the 30-39 age range has the highest mean for both HIV and AIDS diagnoses, followed by the 40-49 age group.
# Younger age groups tend to have lower mean diagnoses, emphasizing the prevalence of HIV/AIDS in middle-aged populations.
#
# Another conclusion that individuals identified as Black exhibit higher rates of both HIV and AIDS diagnoses. Moreover, there is a notable gender disparity, with males showing a significantly higher prevalence. These findings underscore the pronounced dominance of these demographic groups in the overall population, emphasizing the need for targeted interventions and awareness campaigns within these communities.

# %% [markdown]
# # References
#
# https://data.cityofnewyork.us/City-Government/Youth-Engagement-By-Category/pqmq-sk82
#
# https://www.w3schools.com/python/numpy/numpy_random_binomial.asp
#
# https://www.jetbrains.com/pycharm/download/?section=windows
#
# https://www.tutorialspoint.com/statistics/analysis_of_variance.html
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html
#
# https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.boxplot.html
#
# https://seaborn.pydata.org/generated/seaborn.boxplot.html
#
# https://seaborn.pydata.org/generated/seaborn.lineplot.html
#
# https://stackoverflow.com/questions/57975146/how-to-properly-plot-bar-chart-with-matplotlib
#
# https://medium.com/@tttgm/reshaping-data-through-aggregation-3-ways-part-2-10f4a18f45b
